# %%
import pandas as pd
import numpy as np

df = pd.read_csv('df0_1000.csv')
df = df.copy()
not_nulls = []
for col in df.columns:
    not_nulls.append(f"name: {col} ; value: {df[col].notnull().sum()}")
[print(not_nulls[i]) for i in range(100)]


df[df['ipo_price'].notna()]
# Out:
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3524: DtypeWarning: Columns (86) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# name: Unnamed: 0 ; value: 1000
# name: company_name ; value: 1000
# name: company_about ; value: 1000
# name: founded ; value: 1000
# name: business model ; value: 999
# name: employees ; value: 996
# name: funding stage ; value: 994
# name: raised ; value: 319
# name: product stage ; value: 999
# name: status ; value: 1000
# name: geographical markets ; value: 788
# name: products ; value: 511
# name: fund_stage ; value: 384
# name: total_raised ; value: 384
# name: total_rounds ; value: 384
# name: investors ; value: 384
# name: ipo_price ; value: 15
# name: sector_AgriFood-tech & Water ; value: 825
# name: target_industry_Food Retail & Consumption ; value: 76
# name: target_industry_Food Retail & Consumption_Home ; value: 45
# ...
